# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = np.loadtxt('curvevhall.txt')

def interpolation(array_1d):
    idx = []
    for i,j in enumerate (array_1d):
        try:
            if array_1d[i+1]+array_1d[i] < 2 and array_1d[i+1]+array_1d[i] > -2:
                idx.append(i)
                idx_repeat = np.repeat(idx, 20) # choose suitable interpolation points
                saved=np.insert(array_1d,np.array(idx_repeat)+1,np.nan)
                df = pd.DataFrame(saved)
                saved_intp=df.interpolate(method='linear', limit_direction='forward', axis=0)
                np.savetxt('saved.txt',saved_intp)
        except IndexError:
            print('Saved_intp') 
    plt.figure(figsize=(14,4),dpi=80)
    plt.plot(saved_intp,'*--')    
    plt.show()
interpolation(data)
# Out:
# Saved_intp

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = np.loadtxt('curvevhall.txt')

def interpolation(array_1d):
    idx = []
    for i in range (len(array_1d)):
        try:
            if array_1d[i+1]+array_1d[i] < 2 and array_1d[i+1]+array_1d[i] > -2:
                idx.append(i)
                idx_repeat = np.repeat(idx, 5) # choose suitable interpolation points
                saved=np.insert(array_1d,np.array(idx_repeat)+1,np.nan)
                df = pd.DataFrame(saved)
                saved_intp=df.interpolate(method='linear', limit_direction='forward', axis=0)
                np.savetxt('saved.txt',saved_intp)
        except IndexError:
            print('Saved_intp') 
    plt.figure(figsize=(14,4),dpi=80)
    plt.plot(saved_intp,'*--')    
    plt.show()
interpolation(data)
# Out:
# Saved_intp

# %%
y = np.repeat(idx, 5)
Z = np.zeros(60)
dr = pd.DataFrame(y)
df_repeated = pd.concat([df,dr],ignore_index=False)

# %%
df
# Out:
#       curvevhall
# 0     -10.695069
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 1501  -10.995097
# 1502  -10.896829
# 1503  -10.781516
# 1504  -10.841156
# 1505  -10.728666
#
# [1506 rows x 1 columns]

# %%
df1=df.loc[np.where(df.index==idx).repeat(5)].reset_index(drop=True)
#df3=df.loc[df.index.repeat(5)].reset_index(drop=True)
#df1.curvevhall.tolist()
#df2 = df1.drop_duplicates(subset=['curvevhall'], keep='first')

#df2 = df1[df1.curvevhall !=0 ]
#df3 = df1[df1.curvevhall ==0 ]

#df2=((df1[['curvevhall']] == 0).any(axis=1)).reset_index(drop=True)
#df4=pd.concat([df2,df3],axis=1)
#df4.columns=['cu','ze']

#df3.columns=['curvevhall','bool']
#df5=df4['cu'].drop_duplicates()
#a = pd.DataFrame(df5)
b = pd.concat([df2,df3])
#np.savetxt('df_repeated.txt',df2)
#np.savetxt('df_repeated1.txt',df3)
#df4 =df3[df3['bool']==False]
#df3.drop_duplicates(df3[df3['bool']==False])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-790c6ec28b9d> in <module>
# ----> 1 df1=df.loc[np.where(df.index==idx).repeat(5)].reset_index(drop=True)
#       2 #df3=df.loc[df.index.repeat(5)].reset_index(drop=True)
#       3 #df1.curvevhall.tolist()
#       4 #df2 = df1.drop_duplicates(subset=['curvevhall'], keep='first')
#       5
#
# AttributeError: 'tuple' object has no attribute 'repeat'

# %%
df1
# Out:
#       curvevhall
# 0     -10.695069
# 1     -10.695069
# 2     -10.695069
# 3     -10.695069
# 4     -10.695069
# ...          ...
# 7285  -10.728666
# 7286  -10.728666
# 7287  -10.728666
# 7288  -10.728666
# 7289  -10.728666
#
# [7290 rows x 1 columns]

# %%
b
# Out:
#       curvevhall
# 0     -10.695069
# 5     -11.071683
# 10    -10.918886
# 15    -10.845609
# 20    -10.790521
# ...          ...
# 7285  -10.728666
# 7286  -10.728666
# 7287  -10.728666
# 7288  -10.728666
# 7289  -10.728666
#
# [8737 rows x 1 columns]

# %%
df[df.curvevhall==0]
#np.repeat(df[df.curvevhall==0],5)

# %%
idx = []
dZ = pd.DataFrame(np.zeros((5, 1)))
for i,j in enumerate (data['curvevhall']):
    try:
        if data['curvevhall'][i+1]+data['curvevhall'][i] < 2 and data['curvevhall'][i+1]+data['curvevhall'][i] > -2:
            idx.append(i)
            print(idx)
            np.savetxt('s.txt',s)
    except KeyError:
        print('done')

# %%
print(idx)

# %%
dZ = pd.DataFrame(np.zeros((5, 1)))
dZ

# %%
idx = []
for i,j in enumerate (data):
    try:
        if data[i+1]+data[i] < 2 and data[i+1]+data[i] > -2:
            idx.append(i)
            s=np.insert(data,np.array(idx)+1,0)
            print(s)
            #np.savetxt('newdf.txt',newdf)
    except IndexError:
        print('done')

# %%
df.iloc[idx]

# %%
idx

# %%
for k,l in enumerate (data):
    if k==idx:
        s=np.insert(k,idx+1,np.zeros(5))
        print(s)
        #np.savetxt('s.txt',s)

# %%
s==0

# %%
np.zeros(5)

# %%
s+np.zeros(5)
