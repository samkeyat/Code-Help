# %%
import pandas as pd
dat1 = pd.read_csv('sajjad.csv',sep='^',header=None,prefix='X')
dat2=dat1.X0.str.split(',',expand=True)
del dat1['X0']
df = pd.concat([dat1,dat2],axis=1)
df.head()
# Out:
#                                                   0                   1   \
# 0             Eldon Base for stackable storage shelf            platinum
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Barry French
# 2                      Cardinal Slant-D® Ring Binder   Heavy Gauge Vinyl
# 3                                               R380       Clay Rozendal
# 4                           Holmes HEPA Air Purifier      Carlos Soltero
#
#                    2        3        4      5        6   \
# 0  Muhammed MacIntyre        3  -213.25  38.94       35
# 1                 293   457.81   208.16  68.02  Nunavut
# 2        Barry French      293    46.71   8.69     2.99
# 3                 483  1198.97   195.99   3.99  Nunavut
# 4                 515    30.94    21.78   5.94  Nunavut
#
#                              7                               8     9     10  \
# 0                       Nunavut          Storage & Organization   0.8  None
# ...
