# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import netCDF4

# %%
from mpl_toolkits.basemap import Basemap

# %%
a = np.array([1,4,5,7,8])
b = np.array([2,5,4,0,7])
plt.plot(a,b)
plt.show()
