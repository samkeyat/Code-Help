# %%
#!/usr/bin/env python
import numpy as np
import matplotlib
import random
from matplotlib import pyplot as plt

#This is necessary to visualize plots in the notebook
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
def gaussian(x, amplitude=1, mean=50, stddev=5):
    return (amplitude / (sqrt(2*pi) * stddev)) * exp(-(x-mean)**2 / (2*stddev**2))
x = np.linspace(0, 100, 100)
plt.plot(x,gaussian(x))
plt.ylabel('gaussian distribution')
plt.show()

# %%
import matplotlib.pyplot as plt
from numpy import exp, loadtxt, pi, sqrt

from lmfit import Model

#data = loadtxt('model1d_gauss.dat')
#x = data[:, 0]
#y = data[:, 1]
x = np.random.normal(size=100)
y = np.random.normal(size=100)

def gaussian(x, amp, cen, wid):
    """1-d gaussian: gaussian(x, amp, cen, wid)"""
    return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen)**2 / (2*wid**2))


gmodel = Model(gaussian)
result = gmodel.fit(y, x=x, amp=1, cen=0, wid=1)

#print(result.fit_report())

plt.plot(x, y, 'bo')
plt.plot(x, result.init_fit, 'k--', label='initial fit')
plt.plot(x, result.best_fit, 'r-', label='best fit')
plt.legend(loc='best')
plt.show()

# %%
from scipy import optimize

def gaussian(x, amplitude=1, mean=0, stddev=5):
    return (amplitude / (sqrt(2*pi) * stddev)) * exp(-(x-mean)**2 / (2*stddev**2))
x = np.random.normal(size=100)
data = gaussian(x)
popt, _ = optimize.curve_fit(gaussian, x, data)
plt.plot(x, data,'o')
plt.plot(x, gaussian(x, *popt),'+')
